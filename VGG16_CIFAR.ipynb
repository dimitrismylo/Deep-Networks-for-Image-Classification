# %% [markdown]
# <h1><b>Implementation and improvement</b>
# <b>of original VGG-16 using CIFAR dataset</b></h1>

# %% [markdown]
# #Imports

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import numpy as np
import matplotlib.pyplot as plt
import time
import seaborn as sn
import pandas as pd
from sklearn.metrics import confusion_matrix

# %%
def save_model(model, path):
  torch.save(model.state_dict(), path)

def load_model(model, path):
  model.load_state_dict(torch.load(path))

# %% [markdown]
# # Dataset

# %%
data_dir = '/content'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
def load_cifar_dataset():

  """
  Function to load the CIFAR10 dataset that returns a separate train and test set.
  Images resized to 64x64 and normalised using the datasets mean and std.
  """


  train_data = datasets.CIFAR10(data_dir, train=True, download=True,
                             transform=transforms.Compose([
                               transforms.Resize(64),                                                                                
                               transforms.ToTensor(),
                               transforms.Normalize((0.49139968, 0.48215827 ,0.44653124), (0.24703233, 0.24348505, 0.26158768))
                             ]))

  test_data = datasets.CIFAR10(data_dir, train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               transforms.Resize(64),                                      
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize((0.49139968, 0.48215827 ,0.44653124), (0.24703233, 0.24348505, 0.26158768))
                             ]))
  
  return train_data, test_data


def split_train_val(train_data):
  """
  Split data into train and validation sets
  """
  
  train_set, val_set = torch.utils.data.random_split(train_data, [45000, 5000])
  return train_set, val_set

def get_classes(dataset):
  return dataset.classes

# %%
train_data, test_data = load_cifar_dataset()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /content/cifar-10-python.tar.gz to /content
# Files already downloaded and verified

# %%
print(train_data)
print(test_data)

classes = get_classes(train_data)
print(classes)
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: /content
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                Resize(size=64, interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                Normalize(mean=(0.49139968, 0.48215827, 0.44653124), std=(0.24703233, 0.24348505, 0.26158768))
#            )
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: /content
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                Resize(size=64, interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#                Normalize(mean=(0.49139968, 0.48215827, 0.44653124), std=(0.24703233, 0.24348505, 0.26158768))
#            )
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
train_set, val_set = split_train_val(train_data)

# %%
batch_size = 128

train_loader = DataLoader(dataset=train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Initial Visualisation

# %%
examples = enumerate(test_loader)
batch_idx, (example_data, example_targets) = next(examples)

fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='binary_r', interpolation='none')
  plt.title("Ground Truth: {}".format(example_targets[i]))
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# # Original VGG-16 Model

# %%
cfg = {
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
}

class VGG(nn.Module):
    def __init__(self, vgg_name, num_classes, use_bn, init_weights: bool = True, dropout: float=0.5):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name],use_bn)
        self.avgpool = nn.AdaptiveAvgPool2d((7, 7))
        self.classifier = nn.Sequential(
            nn.Linear(512 * 7 * 7, 4096),
            nn.ReLU(True),
            nn.Dropout(p=dropout),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(p=dropout),
            nn.Linear(4096, num_classes),
        )
        self._initialize_weights()
        
    

    def _create_classifer(self,num_classes):
        return nn.Sequential(
            nn.Linear(512 * 7 * 7, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, num_classes),
        )

    def _initialize_weights(self) -> None:
      for m in self.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

    def _make_layers(self, cfg, use_bn):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
              if use_bn:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                            nn.BatchNorm2d(x), # added batch normalizaiton layers
                            nn.ReLU(inplace=True)]
              else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                               nn.ReLU(inplace=True)]


              in_channels = x

        return nn.Sequential(*layers)

# %%
vgg_16 = VGG('VGG16',10, False)

# %%
vgg_16 = vgg_16.to(device)

print(vgg_16)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # Training functions

# %%
def train(model, train_loader, loss_function, optimizer, epoch):
    """
    Training function for one epoch to be called in model_fit function
    """

    model.train()
    train_loss = 0
    train_correct = 0

    for idx, (data, target) in enumerate(train_loader):

        data = data.to(device)
        target = target.to(device)
        
        # compute loss
        output = model(data)
        loss = loss_function(output, target)


        # update using gradient
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #correct = predictions(output, target)

        pred = output.data.max(1, keepdim=True)[1]
        correct = pred.eq(target.data.view_as(pred)).cpu().sum()

        train_correct += correct
        train_loss += loss.data.item()

        if (idx + 1)% 50 == 0:

          print('Epoch Progress: {:.0f}% Done\tCurrent Loss: {:.5f}'.format(100. * (idx + 1) / len(train_loader), loss.data.item()))
    
    # Get training epoch loss and accuracy
    train_loss /= len(train_loader.dataset)
    epoch_acc = float(train_correct) / len(train_loader.dataset)
    print('\nAverage training loss: {:.5f}, Training Accuracy: {}/{} ({:.3f}%)'.format(
      train_loss, train_correct, len(train_loader.dataset),100.0 * epoch_acc))
    return train_loss, epoch_acc

def validate(model, val_loader, loss_function):
    """
    Function to evaluate model at certain epoch on the validation set
    """
    model.eval()
    val_loss = 0
    val_correct = 0

    with torch.no_grad():
      for idx, (data, target) in enumerate(val_loader):

          data = data.to(device)
          target = target.to(device)
          
          output = model(data)
          val_loss += loss_function(output, target).data.item()

          #correct = predictions(output, target)
          #val_correct+=correct

          pred = output.data.max(1, keepdim=True)[1]
          val_correct += pred.eq(target.data.view_as(pred)).cpu().sum()
          
      val_loss /= len(val_loader.dataset)
      epoch_acc = float(val_correct) / len(val_loader.dataset)
      print('Average validation loss: {:.5f}, Validation Accuracy: {}/{} ({:.3f}%)\n'.format(
          val_loss, val_correct, len(val_loader.dataset),100.0 * epoch_acc))
    return val_loss, epoch_acc

def test(model, test_loader):
    model.eval()

    images = []
    labels = []
    predict = []

    correct = 0
    with torch.no_grad():
    
        for idx, (data, target) in enumerate(test_loader):

          data = data.to(device)
          target = target.to(device)

          
          output = model(data)
          
          prediction = output.data.max(1, keepdim=True)[1]
          correct += prediction.eq(target.data.view_as(prediction)).cpu().sum()


          images.append(data)
          labels.append(target)
          predict.append(prediction)

    images = torch.cat(images, dim = 0)
    labels = torch.cat(labels, dim = 0)
    predict = torch.cat(predict, dim = 0)

    acc = float(correct) / len(test_loader.dataset)
    print('\nTest set Accuracy: {}/{} ({:.3f}%)\n'.format(correct, len(test_loader.dataset), 100.0 * acc))
    return images, labels, predict

def model_fit(model, num_epochs, train_loader, val_loader, optimizer, loss_function):
  best_acc = 0.0
  history = { "train_loss": [], "train_acc": [], "val_loss": [], "val_acc": [], "epoch_time": [] }
  start_time = time.time()
  for epoch in range(num_epochs):

    epoch_start_time = time.time()
    print("\nTrain Epoch {}: ".format(epoch+1))

    epoch_train_loss, epoch_train_acc = train(model, train_loader, loss_function, optimizer, epoch)
    epoch_val_loss, epoch_val_acc = validate(model, val_loader, loss_function)

    # Store acuracy and loss scores for current epoch
    history['train_acc'].append(epoch_train_acc)
    history['train_loss'].append(epoch_train_loss)
    history['val_acc'].append(epoch_val_acc)
    history['val_loss'].append(epoch_val_loss)

    epoch_end_time = time.time()
    epoch_time = epoch_end_time - epoch_start_time
    print("Epoch %d of %d. Time taken: %.2fs" % (epoch+1, num_epochs, epoch_time))
    history["epoch_time"].append(epoch_time)
    
  training_time = time.time() - start_time
  print('\nTotal time taken: {:.2f}s'.format(training_time))

  return model, history

# %% [markdown]
# # Plotting functions

# %%
def plot_incorrect(images, labels, pred_labels):
  incorrect_image = []
  incorrect_labels = []
  correct_labels = []


  for i in range(len(images)-1):

    if labels[i] != pred_labels[i]:
      incorrect_image.append(images[i])
      correct_labels.append(labels[i])
      incorrect_labels.append(pred_labels[i])



  fig = plt.figure(figsize = (16, 16))
  rows = 4
  cols = 4

  for i in range(rows*cols):
        ax = fig.add_subplot(rows, cols, i+1)
        image, true_labels, false_label = incorrect_image[i], correct_labels[i], incorrect_labels[i]
        image = image.squeeze()
        image = image.permute(1,2,0)
        true_class = true_labels.cpu().numpy().astype(str)
        incorrect_class = false_label.cpu().numpy()[0].astype(str)

        ax.imshow(image.cpu().numpy(),cmap="gray")
        ax.set_title(f'true label: {true_class} \n' \
                         f'pred label: {incorrect_class} ')
        ax.axis('off')


  fig.subplots_adjust(hspace = 0.3)

# %%
def plot_results(e, h, info, name):
    epochs_range = [i for i in range(e)]

    fig, (loss_plot, acc_plot) = plt.subplots(1, 2, figsize =(12,4))

    loss_plot.plot(epochs_range, h['train_loss'], color='red', label='train loss')
    loss_plot.plot(epochs_range, h['val_loss'], color='green', label='val loss')
    loss_plot.set_title('Epochs - Loss | {}'.format(info))
    loss_plot.legend()

    acc_plot.plot(epochs_range, h['train_acc'], color='red', label='train acc')
    acc_plot.plot(epochs_range, h['val_acc'], color='green', label='val acc')
    acc_plot.set_title('Epochs - Accuracy | {}'.format(info))
    acc_plot.legend()
    plt.savefig(name)
    plt.show()

# %%
def plot_confusion_matrix(labels, pred_labels, classes):

    cf_matrix = confusion_matrix(labels.cpu(), pred_labels.cpu())
    df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *10, index = [i for i in classes],
                     columns = [i for i in classes])
    plt.figure(figsize = (12,7))
    sn.heatmap(df_cm, annot=True)
    return cf_matrix

# %% [markdown]
# # Model Training

# %%
epochs = 50
lr = 0.001    

optimizer = torch.optim.SGD(vgg_16.parameters(), lr=lr, momentum=0.9)
loss_function = nn.CrossEntropyLoss()

vgg_original, history = model_fit(
    model = vgg_16, 
    num_epochs = epochs, 
    train_loader = train_loader, 
    val_loader = val_loader,
    optimizer = optimizer,
    loss_function = loss_function,
  )
# Out:
# Train Epoch 1:
# Epoch Progress: 14% Done	Current Loss: 2.29984
# Epoch Progress: 28% Done	Current Loss: 2.28700
# Epoch Progress: 43% Done	Current Loss: 2.27619
# Epoch Progress: 57% Done	Current Loss: 2.22416
# Epoch Progress: 71% Done	Current Loss: 2.17749
# Epoch Progress: 85% Done	Current Loss: 2.00733
# Epoch Progress: 99% Done	Current Loss: 1.84009
#
# Average training loss: 0.01712, Training Accuracy: 7628/45000 (16.951%)
# Average validation loss: 0.01529, Validation Accuracy: 1443/5000 (28.860%)
#
# Epoch 1 of 50. Time taken: 84.37s
#
# Train Epoch 2:
# Epoch Progress: 14% Done	Current Loss: 1.85045
# Epoch Progress: 28% Done	Current Loss: 1.75582
# Epoch Progress: 43% Done	Current Loss: 1.75745
# Epoch Progress: 57% Done	Current Loss: 1.71529
# Epoch Progress: 71% Done	Current Loss: 1.79546
# Epoch Progress: 85% Done	Current Loss: 1.57195
# Epoch Progress: 99% Done	Current Loss: 1.57550
#
# Average training loss: 0.01371, Training Accuracy: 15707/45000 (34.904%)
# Average validation loss: 0.01293, Validation Accuracy: 2056/5000 (41.120%)
#
# Epoch 2 of 50. Time taken: 87.69s
#
# Train Epoch 3:
# Epoch Progress: 14% Done	Current Loss: 1.55255
# Epoch Progress: 28% Done	Current Loss: 1.66264
# Epoch Progress: 43% Done	Current Loss: 1.53462
# Epoch Progress: 57% Done	Current Loss: 1.63941
# Epoch Progress: 71% Done	Current Loss: 1.61275
# Epoch Progress: 85% Done	Current Loss: 1.42064
# Epoch Progress: 99% Done	Current Loss: 1.41245
#
# Average training loss: 0.01211, Training Accuracy: 19389/45000 (43.087%)
# Average validation loss: 0.01125, Validation Accuracy: 2370/5000 (47.400%)
#
# Epoch 3 of 50. Time taken: 89.48s
#
# Train Epoch 4:
# Epoch Progress: 14% Done	Current Loss: 1.56430
# Epoch Progress: 28% Done	Current Loss: 1.54966
# Epoch Progress: 43% Done	Current Loss: 1.44449
# Epoch Progress: 57% Done	Current Loss: 1.39682
# Epoch Progress: 71% Done	Current Loss: 1.42886
# Epoch Progress: 85% Done	Current Loss: 1.44995
# Epoch Progress: 99% Done	Current Loss: 1.31759
#
# Average training loss: 0.01105, Training Accuracy: 21692/45000 (48.204%)
# Average validation loss: 0.01034, Validation Accuracy: 2639/5000 (52.780%)
#
# Epoch 4 of 50. Time taken: 89.47s
#
# Train Epoch 5:
# Epoch Progress: 14% Done	Current Loss: 1.32413
# Epoch Progress: 28% Done	Current Loss: 1.50160
# Epoch Progress: 43% Done	Current Loss: 1.31066
# Epoch Progress: 57% Done	Current Loss: 1.18468
# Epoch Progress: 71% Done	Current Loss: 1.13551
# Epoch Progress: 85% Done	Current Loss: 1.32474
# Epoch Progress: 99% Done	Current Loss: 1.28173
#
# Average training loss: 0.01023, Training Accuracy: 23626/45000 (52.502%)
# Average validation loss: 0.00955, Validation Accuracy: 2802/5000 (56.040%)
#
# Epoch 5 of 50. Time taken: 89.55s
#
# Train Epoch 6:
# Epoch Progress: 14% Done	Current Loss: 1.17529
# Epoch Progress: 28% Done	Current Loss: 1.14856
# Epoch Progress: 43% Done	Current Loss: 1.22986
# Epoch Progress: 57% Done	Current Loss: 1.46489
# Epoch Progress: 71% Done	Current Loss: 1.37520
# Epoch Progress: 85% Done	Current Loss: 1.36134
# Epoch Progress: 99% Done	Current Loss: 0.94329
#
# Average training loss: 0.00934, Training Accuracy: 25690/45000 (57.089%)
# Average validation loss: 0.00924, Validation Accuracy: 2959/5000 (59.180%)
#
# Epoch 6 of 50. Time taken: 89.45s
#
# Train Epoch 7:
# Epoch Progress: 14% Done	Current Loss: 1.07370
# Epoch Progress: 28% Done	Current Loss: 1.09425
# Epoch Progress: 43% Done	Current Loss: 1.15062
# Epoch Progress: 57% Done	Current Loss: 1.03217
# Epoch Progress: 71% Done	Current Loss: 1.11774
# Epoch Progress: 85% Done	Current Loss: 0.95276
# Epoch Progress: 99% Done	Current Loss: 0.99801
#
# Average training loss: 0.00857, Training Accuracy: 27322/45000 (60.716%)
# Average validation loss: 0.00873, Validation Accuracy: 3012/5000 (60.240%)
#
# Epoch 7 of 50. Time taken: 89.48s
#
# Train Epoch 8:
# Epoch Progress: 14% Done	Current Loss: 1.14214
# Epoch Progress: 28% Done	Current Loss: 1.08664
# Epoch Progress: 43% Done	Current Loss: 1.16701
# Epoch Progress: 57% Done	Current Loss: 0.93519
# Epoch Progress: 71% Done	Current Loss: 1.28554
# Epoch Progress: 85% Done	Current Loss: 0.90863
# Epoch Progress: 99% Done	Current Loss: 1.09332
#
# Average training loss: 0.00789, Training Accuracy: 28840/45000 (64.089%)
# Average validation loss: 0.00776, Validation Accuracy: 3256/5000 (65.120%)
#
# Epoch 8 of 50. Time taken: 89.53s
#
# Train Epoch 9:
# Epoch Progress: 14% Done	Current Loss: 0.84617
# Epoch Progress: 28% Done	Current Loss: 1.02139
# Epoch Progress: 43% Done	Current Loss: 0.99022
# Epoch Progress: 57% Done	Current Loss: 0.97126
# Epoch Progress: 71% Done	Current Loss: 0.84255
# Epoch Progress: 85% Done	Current Loss: 0.94134
# Epoch Progress: 99% Done	Current Loss: 0.71039
#
# Average training loss: 0.00711, Training Accuracy: 30465/45000 (67.700%)
# Average validation loss: 0.00782, Validation Accuracy: 3310/5000 (66.200%)
#
# Epoch 9 of 50. Time taken: 89.54s
#
# Train Epoch 10:
# Epoch Progress: 14% Done	Current Loss: 0.81503
# Epoch Progress: 28% Done	Current Loss: 0.69097
# Epoch Progress: 43% Done	Current Loss: 0.80269
# Epoch Progress: 57% Done	Current Loss: 0.81561
# Epoch Progress: 71% Done	Current Loss: 0.81421
# Epoch Progress: 85% Done	Current Loss: 0.84070
# Epoch Progress: 99% Done	Current Loss: 0.78098
#
# Average training loss: 0.00649, Training Accuracy: 31766/45000 (70.591%)
# Average validation loss: 0.00684, Validation Accuracy: 3518/5000 (70.360%)
#
# Epoch 10 of 50. Time taken: 89.49s
#
# Train Epoch 11:
# Epoch Progress: 14% Done	Current Loss: 0.68638
# Epoch Progress: 28% Done	Current Loss: 0.75867
# Epoch Progress: 43% Done	Current Loss: 0.66931
# Epoch Progress: 57% Done	Current Loss: 0.75747
# Epoch Progress: 71% Done	Current Loss: 0.78855
# Epoch Progress: 85% Done	Current Loss: 0.70432
# Epoch Progress: 99% Done	Current Loss: 0.73830
#
# Average training loss: 0.00591, Training Accuracy: 33076/45000 (73.502%)
# Average validation loss: 0.00685, Validation Accuracy: 3522/5000 (70.440%)
#
# Epoch 11 of 50. Time taken: 89.53s
#
# Train Epoch 12:
# Epoch Progress: 14% Done	Current Loss: 0.65392
# Epoch Progress: 28% Done	Current Loss: 0.70491
# Epoch Progress: 43% Done	Current Loss: 0.69646
# Epoch Progress: 57% Done	Current Loss: 0.67936
# Epoch Progress: 71% Done	Current Loss: 0.80905
# Epoch Progress: 85% Done	Current Loss: 0.63416
# Epoch Progress: 99% Done	Current Loss: 0.49121
#
# Average training loss: 0.00531, Training Accuracy: 34162/45000 (75.916%)
# Average validation loss: 0.00627, Validation Accuracy: 3638/5000 (72.760%)
#
# Epoch 12 of 50. Time taken: 89.54s
#
# Train Epoch 13:
# Epoch Progress: 14% Done	Current Loss: 0.53767
# Epoch Progress: 28% Done	Current Loss: 0.65661
# Epoch Progress: 43% Done	Current Loss: 0.57220
# Epoch Progress: 57% Done	Current Loss: 0.55829
# Epoch Progress: 71% Done	Current Loss: 0.50816
# Epoch Progress: 85% Done	Current Loss: 0.65212
# Epoch Progress: 99% Done	Current Loss: 0.66189
#
# Average training loss: 0.00477, Training Accuracy: 35388/45000 (78.640%)
# Average validation loss: 0.00613, Validation Accuracy: 3716/5000 (74.320%)
#
# Epoch 13 of 50. Time taken: 89.53s
#
# Train Epoch 14:
# Epoch Progress: 14% Done	Current Loss: 0.55175
# Epoch Progress: 28% Done	Current Loss: 0.49157
# Epoch Progress: 43% Done	Current Loss: 0.55099
# Epoch Progress: 57% Done	Current Loss: 0.51306
# Epoch Progress: 71% Done	Current Loss: 0.40054
# Epoch Progress: 85% Done	Current Loss: 0.78646
# Epoch Progress: 99% Done	Current Loss: 0.50864
#
# Average training loss: 0.00423, Training Accuracy: 36411/45000 (80.913%)
# Average validation loss: 0.00594, Validation Accuracy: 3742/5000 (74.840%)
#
# Epoch 14 of 50. Time taken: 89.53s
#
# Train Epoch 15:
# Epoch Progress: 14% Done	Current Loss: 0.33214
# Epoch Progress: 28% Done	Current Loss: 0.45636
# Epoch Progress: 43% Done	Current Loss: 0.37349
# Epoch Progress: 57% Done	Current Loss: 0.50097
# Epoch Progress: 71% Done	Current Loss: 0.35834
# Epoch Progress: 85% Done	Current Loss: 0.56824
# Epoch Progress: 99% Done	Current Loss: 0.49620
#
# Average training loss: 0.00366, Training Accuracy: 37546/45000 (83.436%)
# Average validation loss: 0.00628, Validation Accuracy: 3728/5000 (74.560%)
#
# Epoch 15 of 50. Time taken: 89.61s
#
# Train Epoch 16:
# Epoch Progress: 14% Done	Current Loss: 0.43477
# Epoch Progress: 28% Done	Current Loss: 0.40605
# Epoch Progress: 43% Done	Current Loss: 0.45565
# Epoch Progress: 57% Done	Current Loss: 0.45042
# Epoch Progress: 71% Done	Current Loss: 0.34577
# Epoch Progress: 85% Done	Current Loss: 0.37040
# Epoch Progress: 99% Done	Current Loss: 0.41996
#
# Average training loss: 0.00322, Training Accuracy: 38385/45000 (85.300%)
# Average validation loss: 0.00639, Validation Accuracy: 3721/5000 (74.420%)
#
# Epoch 16 of 50. Time taken: 89.52s
#
# Train Epoch 17:
# Epoch Progress: 14% Done	Current Loss: 0.25594
# Epoch Progress: 28% Done	Current Loss: 0.52778
# Epoch Progress: 43% Done	Current Loss: 0.32278
# Epoch Progress: 57% Done	Current Loss: 0.34243
# Epoch Progress: 71% Done	Current Loss: 0.39802
# Epoch Progress: 85% Done	Current Loss: 0.35831
# Epoch Progress: 99% Done	Current Loss: 0.59650
#
# Average training loss: 0.00280, Training Accuracy: 39220/45000 (87.156%)
# Average validation loss: 0.00695, Validation Accuracy: 3618/5000 (72.360%)
#
# Epoch 17 of 50. Time taken: 89.60s
#
# Train Epoch 18:
# Epoch Progress: 14% Done	Current Loss: 0.24548
# Epoch Progress: 28% Done	Current Loss: 0.25808
# Epoch Progress: 43% Done	Current Loss: 0.38798
# Epoch Progress: 57% Done	Current Loss: 0.22364
# Epoch Progress: 71% Done	Current Loss: 0.41189
# Epoch Progress: 85% Done	Current Loss: 0.36084
# Epoch Progress: 99% Done	Current Loss: 0.17801
#
# Average training loss: 0.00231, Training Accuracy: 40210/45000 (89.356%)
# Average validation loss: 0.00678, Validation Accuracy: 3783/5000 (75.660%)
#
# Epoch 18 of 50. Time taken: 89.51s
#
# Train Epoch 19:
# Epoch Progress: 14% Done	Current Loss: 0.35354
# Epoch Progress: 28% Done	Current Loss: 0.17220
# Epoch Progress: 43% Done	Current Loss: 0.34923
# Epoch Progress: 57% Done	Current Loss: 0.26684
# Epoch Progress: 71% Done	Current Loss: 0.36627
# Epoch Progress: 85% Done	Current Loss: 0.22832
# Epoch Progress: 99% Done	Current Loss: 0.27307
#
# Average training loss: 0.00186, Training Accuracy: 41227/45000 (91.616%)
# Average validation loss: 0.00710, Validation Accuracy: 3724/5000 (74.480%)
#
# Epoch 19 of 50. Time taken: 89.46s
#
# Train Epoch 20:
# Epoch Progress: 14% Done	Current Loss: 0.17055
# Epoch Progress: 28% Done	Current Loss: 0.15704
# Epoch Progress: 43% Done	Current Loss: 0.20410
# Epoch Progress: 57% Done	Current Loss: 0.27312
# Epoch Progress: 71% Done	Current Loss: 0.13221
# Epoch Progress: 85% Done	Current Loss: 0.31764
# Epoch Progress: 99% Done	Current Loss: 0.21665
#
# Average training loss: 0.00170, Training Accuracy: 41525/45000 (92.278%)
# Average validation loss: 0.00815, Validation Accuracy: 3736/5000 (74.720%)
#
# Epoch 20 of 50. Time taken: 89.50s
#
# Train Epoch 21:
# Epoch Progress: 14% Done	Current Loss: 0.08917
# Epoch Progress: 28% Done	Current Loss: 0.06594
# Epoch Progress: 43% Done	Current Loss: 0.21897
# Epoch Progress: 57% Done	Current Loss: 0.24128
# Epoch Progress: 71% Done	Current Loss: 0.10960
# Epoch Progress: 85% Done	Current Loss: 0.22812
# Epoch Progress: 99% Done	Current Loss: 0.10363
#
# Average training loss: 0.00130, Training Accuracy: 42312/45000 (94.027%)
# Average validation loss: 0.00836, Validation Accuracy: 3752/5000 (75.040%)
#
# Epoch 21 of 50. Time taken: 89.57s
#
# Train Epoch 22:
# Epoch Progress: 14% Done	Current Loss: 0.09691
# Epoch Progress: 28% Done	Current Loss: 0.07206
# Epoch Progress: 43% Done	Current Loss: 0.12175
# Epoch Progress: 57% Done	Current Loss: 0.15080
# Epoch Progress: 71% Done	Current Loss: 0.11895
# Epoch Progress: 85% Done	Current Loss: 0.10672
# Epoch Progress: 99% Done	Current Loss: 0.10597
#
# Average training loss: 0.00109, Training Accuracy: 42784/45000 (95.076%)
# Average validation loss: 0.00803, Validation Accuracy: 3842/5000 (76.840%)
#
# Epoch 22 of 50. Time taken: 89.62s
#
# Train Epoch 23:
# Epoch Progress: 14% Done	Current Loss: 0.08497
# Epoch Progress: 28% Done	Current Loss: 0.16929
# Epoch Progress: 43% Done	Current Loss: 0.12958
# Epoch Progress: 57% Done	Current Loss: 0.13504
# Epoch Progress: 71% Done	Current Loss: 0.08882
# Epoch Progress: 85% Done	Current Loss: 0.15332
# Epoch Progress: 99% Done	Current Loss: 0.20943
#
# Average training loss: 0.00096, Training Accuracy: 43013/45000 (95.584%)
# Average validation loss: 0.00874, Validation Accuracy: 3721/5000 (74.420%)
#
# Epoch 23 of 50. Time taken: 89.68s
#
# Train Epoch 24:
# Epoch Progress: 14% Done	Current Loss: 0.10092
# Epoch Progress: 28% Done	Current Loss: 0.13026
# Epoch Progress: 43% Done	Current Loss: 0.06606
# Epoch Progress: 57% Done	Current Loss: 0.10511
# Epoch Progress: 71% Done	Current Loss: 0.10377
# Epoch Progress: 85% Done	Current Loss: 0.14547
# Epoch Progress: 99% Done	Current Loss: 0.09294
#
# Average training loss: 0.00087, Training Accuracy: 43267/45000 (96.149%)
# Average validation loss: 0.00950, Validation Accuracy: 3722/5000 (74.440%)
#
# Epoch 24 of 50. Time taken: 89.63s
#
# Train Epoch 25:
# Epoch Progress: 14% Done	Current Loss: 0.10208
# Epoch Progress: 28% Done	Current Loss: 0.06109
# Epoch Progress: 43% Done	Current Loss: 0.11643
# Epoch Progress: 57% Done	Current Loss: 0.06421
# Epoch Progress: 71% Done	Current Loss: 0.04765
# Epoch Progress: 85% Done	Current Loss: 0.06466
# Epoch Progress: 99% Done	Current Loss: 0.06324
#
# Average training loss: 0.00073, Training Accuracy: 43492/45000 (96.649%)
# Average validation loss: 0.01022, Validation Accuracy: 3671/5000 (73.420%)
#
# Epoch 25 of 50. Time taken: 89.59s
#
# Train Epoch 26:
# Epoch Progress: 14% Done	Current Loss: 0.04896
# Epoch Progress: 28% Done	Current Loss: 0.10410
# Epoch Progress: 43% Done	Current Loss: 0.04484
# Epoch Progress: 57% Done	Current Loss: 0.05106
# Epoch Progress: 71% Done	Current Loss: 0.12453
# Epoch Progress: 85% Done	Current Loss: 0.05726
# Epoch Progress: 99% Done	Current Loss: 0.12963
#
# Average training loss: 0.00062, Training Accuracy: 43718/45000 (97.151%)
# Average validation loss: 0.00974, Validation Accuracy: 3695/5000 (73.900%)
#
# Epoch 26 of 50. Time taken: 89.55s
#
# Train Epoch 27:
# Epoch Progress: 14% Done	Current Loss: 0.06287
# Epoch Progress: 28% Done	Current Loss: 0.07479
# Epoch Progress: 43% Done	Current Loss: 0.04585
# Epoch Progress: 57% Done	Current Loss: 0.05472
# Epoch Progress: 71% Done	Current Loss: 0.16889
# Epoch Progress: 85% Done	Current Loss: 0.13877
# Epoch Progress: 99% Done	Current Loss: 0.06170
#
# Average training loss: 0.00057, Training Accuracy: 43872/45000 (97.493%)
# Average validation loss: 0.00994, Validation Accuracy: 3749/5000 (74.980%)
#
# Epoch 27 of 50. Time taken: 89.62s
#
# Train Epoch 28:
# Epoch Progress: 14% Done	Current Loss: 0.03680
# Epoch Progress: 28% Done	Current Loss: 0.03195
# Epoch Progress: 43% Done	Current Loss: 0.05075
# Epoch Progress: 57% Done	Current Loss: 0.06232
# Epoch Progress: 71% Done	Current Loss: 0.03617
# Epoch Progress: 85% Done	Current Loss: 0.11010
# Epoch Progress: 99% Done	Current Loss: 0.05793
#
# Average training loss: 0.00045, Training Accuracy: 44119/45000 (98.042%)
# Average validation loss: 0.01037, Validation Accuracy: 3809/5000 (76.180%)
#
# Epoch 28 of 50. Time taken: 89.42s
#
# Train Epoch 29:
# Epoch Progress: 14% Done	Current Loss: 0.06980
# Epoch Progress: 28% Done	Current Loss: 0.02054
# Epoch Progress: 43% Done	Current Loss: 0.08132
# Epoch Progress: 57% Done	Current Loss: 0.02474
# Epoch Progress: 71% Done	Current Loss: 0.04051
# Epoch Progress: 85% Done	Current Loss: 0.04648
# Epoch Progress: 99% Done	Current Loss: 0.05673
#
# Average training loss: 0.00038, Training Accuracy: 44259/45000 (98.353%)
# Average validation loss: 0.00992, Validation Accuracy: 3863/5000 (77.260%)
#
# Epoch 29 of 50. Time taken: 89.57s
#
# Train Epoch 30:
# Epoch Progress: 14% Done	Current Loss: 0.02988
# Epoch Progress: 28% Done	Current Loss: 0.02898
# Epoch Progress: 43% Done	Current Loss: 0.09137
# Epoch Progress: 57% Done	Current Loss: 0.06898
# Epoch Progress: 71% Done	Current Loss: 0.03789
# Epoch Progress: 85% Done	Current Loss: 0.02634
# Epoch Progress: 99% Done	Current Loss: 0.11575
#
# Average training loss: 0.00043, Training Accuracy: 44139/45000 (98.087%)
# Average validation loss: 0.01028, Validation Accuracy: 3805/5000 (76.100%)
#
# Epoch 30 of 50. Time taken: 89.56s
#
# Train Epoch 31:
# Epoch Progress: 14% Done	Current Loss: 0.01852
# Epoch Progress: 28% Done	Current Loss: 0.04719
# Epoch Progress: 43% Done	Current Loss: 0.02122
# Epoch Progress: 57% Done	Current Loss: 0.01319
# Epoch Progress: 71% Done	Current Loss: 0.04341
# Epoch Progress: 85% Done	Current Loss: 0.01269
# Epoch Progress: 99% Done	Current Loss: 0.08035
#
# Average training loss: 0.00033, Training Accuracy: 44386/45000 (98.636%)
# Average validation loss: 0.01203, Validation Accuracy: 3763/5000 (75.260%)
#
# Epoch 31 of 50. Time taken: 89.68s
#
# Train Epoch 32:
# Epoch Progress: 14% Done	Current Loss: 0.01993
# Epoch Progress: 28% Done	Current Loss: 0.01065
# Epoch Progress: 43% Done	Current Loss: 0.02853
# Epoch Progress: 57% Done	Current Loss: 0.09250
# Epoch Progress: 71% Done	Current Loss: 0.07700
# Epoch Progress: 85% Done	Current Loss: 0.02225
# Epoch Progress: 99% Done	Current Loss: 0.05348
#
# Average training loss: 0.00031, Training Accuracy: 44395/45000 (98.656%)
# Average validation loss: 0.01172, Validation Accuracy: 3824/5000 (76.480%)
#
# Epoch 32 of 50. Time taken: 89.51s
#
# Train Epoch 33:
# Epoch Progress: 14% Done	Current Loss: 0.01553
# Epoch Progress: 28% Done	Current Loss: 0.01892
# Epoch Progress: 43% Done	Current Loss: 0.03564
# Epoch Progress: 57% Done	Current Loss: 0.03229
# Epoch Progress: 71% Done	Current Loss: 0.02683
# Epoch Progress: 85% Done	Current Loss: 0.03638
# Epoch Progress: 99% Done	Current Loss: 0.02667
#
# Average training loss: 0.00029, Training Accuracy: 44442/45000 (98.760%)
# Average validation loss: 0.01130, Validation Accuracy: 3805/5000 (76.100%)
#
# Epoch 33 of 50. Time taken: 90.33s
#
# Train Epoch 34:
# Epoch Progress: 14% Done	Current Loss: 0.02481
# Epoch Progress: 28% Done	Current Loss: 0.01549
# Epoch Progress: 43% Done	Current Loss: 0.00538
# Epoch Progress: 57% Done	Current Loss: 0.01675
# Epoch Progress: 71% Done	Current Loss: 0.01978
# Epoch Progress: 85% Done	Current Loss: 0.05131
# Epoch Progress: 99% Done	Current Loss: 0.06211
#
# Average training loss: 0.00026, Training Accuracy: 44493/45000 (98.873%)
# Average validation loss: 0.01059, Validation Accuracy: 3839/5000 (76.780%)
#
# Epoch 34 of 50. Time taken: 90.35s
#
# Train Epoch 35:
# Epoch Progress: 14% Done	Current Loss: 0.00420
# Epoch Progress: 28% Done	Current Loss: 0.07769
# Epoch Progress: 43% Done	Current Loss: 0.01696
# Epoch Progress: 57% Done	Current Loss: 0.03904
# Epoch Progress: 71% Done	Current Loss: 0.07464
# Epoch Progress: 85% Done	Current Loss: 0.05180
# Epoch Progress: 99% Done	Current Loss: 0.01992
#
# Average training loss: 0.00024, Training Accuracy: 44530/45000 (98.956%)
# Average validation loss: 0.01154, Validation Accuracy: 3826/5000 (76.520%)
#
# Epoch 35 of 50. Time taken: 89.71s
#
# Train Epoch 36:
# Epoch Progress: 14% Done	Current Loss: 0.01075
# Epoch Progress: 28% Done	Current Loss: 0.01312
# Epoch Progress: 43% Done	Current Loss: 0.04833
# Epoch Progress: 57% Done	Current Loss: 0.04026
# Epoch Progress: 71% Done	Current Loss: 0.00617
# Epoch Progress: 85% Done	Current Loss: 0.02113
# Epoch Progress: 99% Done	Current Loss: 0.06374
#
# Average training loss: 0.00019, Training Accuracy: 44633/45000 (99.184%)
# Average validation loss: 0.01196, Validation Accuracy: 3762/5000 (75.240%)
#
# Epoch 36 of 50. Time taken: 89.54s
#
# Train Epoch 37:
# Epoch Progress: 14% Done	Current Loss: 0.01781
# Epoch Progress: 28% Done	Current Loss: 0.03226
# Epoch Progress: 43% Done	Current Loss: 0.01110
# Epoch Progress: 57% Done	Current Loss: 0.03989
# Epoch Progress: 71% Done	Current Loss: 0.06616
# Epoch Progress: 85% Done	Current Loss: 0.01329
# Epoch Progress: 99% Done	Current Loss: 0.02470
#
# Average training loss: 0.00029, Training Accuracy: 44429/45000 (98.731%)
# Average validation loss: 0.01178, Validation Accuracy: 3823/5000 (76.460%)
#
# Epoch 37 of 50. Time taken: 89.66s
#
# Train Epoch 38:
# Epoch Progress: 14% Done	Current Loss: 0.01851
# Epoch Progress: 28% Done	Current Loss: 0.01076
# Epoch Progress: 43% Done	Current Loss: 0.02605
# Epoch Progress: 57% Done	Current Loss: 0.02244
# Epoch Progress: 71% Done	Current Loss: 0.00991
# Epoch Progress: 85% Done	Current Loss: 0.04727
# Epoch Progress: 99% Done	Current Loss: 0.02480
#
# Average training loss: 0.00023, Training Accuracy: 44575/45000 (99.056%)
# Average validation loss: 0.01133, Validation Accuracy: 3819/5000 (76.380%)
#
# Epoch 38 of 50. Time taken: 89.62s
#
# Train Epoch 39:
# Epoch Progress: 14% Done	Current Loss: 0.02685
# Epoch Progress: 28% Done	Current Loss: 0.00582
# Epoch Progress: 43% Done	Current Loss: 0.03919
# Epoch Progress: 57% Done	Current Loss: 0.01588
# Epoch Progress: 71% Done	Current Loss: 0.01025
# Epoch Progress: 85% Done	Current Loss: 0.03904
# Epoch Progress: 99% Done	Current Loss: 0.00495
#
# Average training loss: 0.00020, Training Accuracy: 44607/45000 (99.127%)
# Average validation loss: 0.01228, Validation Accuracy: 3815/5000 (76.300%)
#
# Epoch 39 of 50. Time taken: 89.50s
#
# Train Epoch 40:
# Epoch Progress: 14% Done	Current Loss: 0.01348
# Epoch Progress: 28% Done	Current Loss: 0.00165
# Epoch Progress: 43% Done	Current Loss: 0.00935
# Epoch Progress: 57% Done	Current Loss: 0.00734
# Epoch Progress: 71% Done	Current Loss: 0.00903
# Epoch Progress: 85% Done	Current Loss: 0.02269
# Epoch Progress: 99% Done	Current Loss: 0.01034
#
# Average training loss: 0.00017, Training Accuracy: 44687/45000 (99.304%)
# Average validation loss: 0.01215, Validation Accuracy: 3779/5000 (75.580%)
#
# Epoch 40 of 50. Time taken: 89.55s
#
# Train Epoch 41:
# Epoch Progress: 14% Done	Current Loss: 0.03487
# Epoch Progress: 28% Done	Current Loss: 0.01936
# Epoch Progress: 43% Done	Current Loss: 0.01981
# Epoch Progress: 57% Done	Current Loss: 0.00377
# Epoch Progress: 71% Done	Current Loss: 0.01286
# Epoch Progress: 85% Done	Current Loss: 0.01050
# Epoch Progress: 99% Done	Current Loss: 0.00347
#
# Average training loss: 0.00020, Training Accuracy: 44604/45000 (99.120%)
# Average validation loss: 0.01104, Validation Accuracy: 3841/5000 (76.820%)
#
# Epoch 41 of 50. Time taken: 89.61s
#
# Train Epoch 42:
# Epoch Progress: 14% Done	Current Loss: 0.01729
# Epoch Progress: 28% Done	Current Loss: 0.01707
# Epoch Progress: 43% Done	Current Loss: 0.00940
# Epoch Progress: 57% Done	Current Loss: 0.03324
# Epoch Progress: 71% Done	Current Loss: 0.02680
# Epoch Progress: 85% Done	Current Loss: 0.02874
# Epoch Progress: 99% Done	Current Loss: 0.00353
#
# Average training loss: 0.00011, Training Accuracy: 44796/45000 (99.547%)
# Average validation loss: 0.01313, Validation Accuracy: 3815/5000 (76.300%)
#
# Epoch 42 of 50. Time taken: 89.55s
#
# Train Epoch 43:
# Epoch Progress: 14% Done	Current Loss: 0.02382
# Epoch Progress: 28% Done	Current Loss: 0.00475
# Epoch Progress: 43% Done	Current Loss: 0.00204
# Epoch Progress: 57% Done	Current Loss: 0.01488
# Epoch Progress: 71% Done	Current Loss: 0.01401
# Epoch Progress: 85% Done	Current Loss: 0.00129
# Epoch Progress: 99% Done	Current Loss: 0.02415
#
# Average training loss: 0.00013, Training Accuracy: 44753/45000 (99.451%)
# Average validation loss: 0.01276, Validation Accuracy: 3874/5000 (77.480%)
#
# Epoch 43 of 50. Time taken: 89.56s
#
# Train Epoch 44:
# Epoch Progress: 14% Done	Current Loss: 0.00283
# Epoch Progress: 28% Done	Current Loss: 0.00287
# Epoch Progress: 43% Done	Current Loss: 0.00102
# Epoch Progress: 57% Done	Current Loss: 0.00161
# Epoch Progress: 71% Done	Current Loss: 0.00397
# Epoch Progress: 85% Done	Current Loss: 0.01540
# Epoch Progress: 99% Done	Current Loss: 0.00044
#
# Average training loss: 0.00007, Training Accuracy: 44879/45000 (99.731%)
# Average validation loss: 0.01420, Validation Accuracy: 3833/5000 (76.660%)
#
# Epoch 44 of 50. Time taken: 89.38s
#
# Train Epoch 45:
# Epoch Progress: 14% Done	Current Loss: 0.00260
# Epoch Progress: 28% Done	Current Loss: 0.04045
# Epoch Progress: 43% Done	Current Loss: 0.01496
# Epoch Progress: 57% Done	Current Loss: 0.01636
# Epoch Progress: 71% Done	Current Loss: 0.09942
# Epoch Progress: 85% Done	Current Loss: 0.00692
# Epoch Progress: 99% Done	Current Loss: 0.00905
#
# Average training loss: 0.00012, Training Accuracy: 44772/45000 (99.493%)
# Average validation loss: 0.01221, Validation Accuracy: 3841/5000 (76.820%)
#
# Epoch 45 of 50. Time taken: 89.54s
#
# Train Epoch 46:
# Epoch Progress: 14% Done	Current Loss: 0.01426
# Epoch Progress: 28% Done	Current Loss: 0.01541
# Epoch Progress: 43% Done	Current Loss: 0.00137
# Epoch Progress: 57% Done	Current Loss: 0.01041
# Epoch Progress: 71% Done	Current Loss: 0.01533
# Epoch Progress: 85% Done	Current Loss: 0.01852
# Epoch Progress: 99% Done	Current Loss: 0.04936
#
# Average training loss: 0.00015, Training Accuracy: 44707/45000 (99.349%)
# Average validation loss: 0.01298, Validation Accuracy: 3785/5000 (75.700%)
#
# Epoch 46 of 50. Time taken: 89.52s
#
# Train Epoch 47:
# Epoch Progress: 14% Done	Current Loss: 0.00529
# Epoch Progress: 28% Done	Current Loss: 0.02526
# Epoch Progress: 43% Done	Current Loss: 0.00249
# Epoch Progress: 57% Done	Current Loss: 0.01729
# Epoch Progress: 71% Done	Current Loss: 0.01792
# Epoch Progress: 85% Done	Current Loss: 0.00670
# Epoch Progress: 99% Done	Current Loss: 0.00587
#
# Average training loss: 0.00014, Training Accuracy: 44729/45000 (99.398%)
# Average validation loss: 0.01315, Validation Accuracy: 3819/5000 (76.380%)
#
# Epoch 47 of 50. Time taken: 89.41s
#
# Train Epoch 48:
# Epoch Progress: 14% Done	Current Loss: 0.00699
# Epoch Progress: 28% Done	Current Loss: 0.00325
# Epoch Progress: 43% Done	Current Loss: 0.03561
# Epoch Progress: 57% Done	Current Loss: 0.04003
# Epoch Progress: 71% Done	Current Loss: 0.00220
# Epoch Progress: 85% Done	Current Loss: 0.00189
# Epoch Progress: 99% Done	Current Loss: 0.00419
#
# Average training loss: 0.00012, Training Accuracy: 44782/45000 (99.516%)
# Average validation loss: 0.01299, Validation Accuracy: 3856/5000 (77.120%)
#
# Epoch 48 of 50. Time taken: 89.47s
#
# Train Epoch 49:
# Epoch Progress: 14% Done	Current Loss: 0.00165
# Epoch Progress: 28% Done	Current Loss: 0.00604
# Epoch Progress: 43% Done	Current Loss: 0.00884
# Epoch Progress: 57% Done	Current Loss: 0.00543
# Epoch Progress: 71% Done	Current Loss: 0.05141
# Epoch Progress: 85% Done	Current Loss: 0.03384
# Epoch Progress: 99% Done	Current Loss: 0.01379
#
# Average training loss: 0.00013, Training Accuracy: 44729/45000 (99.398%)
# Average validation loss: 0.01309, Validation Accuracy: 3786/5000 (75.720%)
#
# Epoch 49 of 50. Time taken: 89.54s
#
# Train Epoch 50:
# Epoch Progress: 14% Done	Current Loss: 0.01023
# Epoch Progress: 28% Done	Current Loss: 0.00094
# Epoch Progress: 43% Done	Current Loss: 0.02104
# Epoch Progress: 57% Done	Current Loss: 0.00629
# Epoch Progress: 71% Done	Current Loss: 0.00369
# Epoch Progress: 85% Done	Current Loss: 0.00338
# Epoch Progress: 99% Done	Current Loss: 0.02288
#
# Average training loss: 0.00009, Training Accuracy: 44812/45000 (99.582%)
# Average validation loss: 0.01365, Validation Accuracy: 3850/5000 (77.000%)
#
# Epoch 50 of 50. Time taken: 89.53s
#
# Total time taken: 4471.75s

# %%
original_model = '/content/vgg16_mnist.pth'

save_model(vgg_original, original_model)

# %%
images, labels, pred_labels = test(vgg_original, test_loader)
# Out:
# Test set Accuracy: 7628/10000 (76.280%)

# %%
plot_results(epochs, history, info='VGG', name='original_VGG_16_plot')

# %%
plot_confusion_matrix(labels, pred_labels, classes)
# Out:
# array([[865,   7,  30,  16,   7,   3,   7,   8,  45,  12],
#        [ 31, 825,   4,   8,   5,   1,  11,   5,  36,  74],
#        [ 75,   2, 689,  47,  55,  33,  41,  43,  12,   3],
#        [ 24,   3,  83, 628,  48,  74,  62,  50,  17,  11],
#        [ 14,   2,  71,  63, 717,  13,  43,  66,  11,   0],
#        [ 11,   3,  52, 229,  39, 562,  20,  66,  12,   6],
#        [ 11,   1,  42,  44,  25,   7, 843,  12,  12,   3],
#        [ 18,   0,  24,  44,  35,  26,   2, 838,   4,   9],
#        [ 65,  16,   6,  12,   7,   3,   3,   4, 874,  10],
#        [ 49,  60,   6,  21,   4,   3,   8,  27,  35, 787]])

# %%
plot_incorrect(images, labels, pred_labels)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # **Improvement on VGG-16**

# %% [markdown]
# # Data Augmentation

# %%
data_dir = '/content/'

def load_augmented_cifar_dataset():

  """
  Function to load the cifar dataset that returns a separate train and test set.
  Images resized to 64x64 and normalised using the datasets mean and std. This time data augmnentation
  is applied.
  """


  train_data = datasets.CIFAR10(data_dir, train=True, download=True,
                             transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.RandomAffine(degrees=20, translate=(0.2,0.2), scale=(0.7,1.3)),                                                                             
                               transforms.ToTensor(),
                               transforms.Normalize((0.49139968, 0.48215827 ,0.44653124), (0.24703233, 0.24348505, 0.26158768))
                             ]))

  test_data = datasets.CIFAR10(data_dir, train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               transforms.Resize(64),                                      
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize((0.49139968, 0.48215827 ,0.44653124), (0.24703233, 0.24348505, 0.26158768))
                             ]))
  
  return train_data, test_data

# %%
train_data, test_data = load_augmented_cifar_dataset()

classes = get_classes(train_data)

train_set, val_set = split_train_val(train_data)

batch_size = 128

train_loader = DataLoader(dataset=train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
examples = enumerate(train_loader)
batch_idx, (example_data, example_targets) = next(examples)

fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Ground Truth: {}".format(example_targets[i]))
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# # Improved model

# %%
cfg = {
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
}

class VGG_improved(nn.Module):
    def __init__(self, vgg_name, num_classes, use_bn, init_weights: bool = True, dropout: float=0.5):
        super(VGG_improved, self).__init__()
        self.features = self._make_layers(cfg[vgg_name],use_bn)
        self.avgpool = nn.AdaptiveMaxPool2d((5, 5))
        self.classifier = nn.Sequential(
            nn.Linear(512 * 5 * 5, 4096),
            nn.ReLU(True),
            nn.Dropout(p=dropout),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(p=dropout),
            nn.Linear(4096, num_classes),
        )
        self._initialize_weights()
        
  

    def _initialize_weights(self) -> None:
      for m in self.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

    def _make_layers(self, cfg, use_bn):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
              if use_bn:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                            nn.BatchNorm2d(x), # added batch normalizaiton layers
                            nn.ReLU(inplace=True)]
              else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                               nn.ReLU(inplace=True)]


              
              
              in_channels = x

        return nn.Sequential(*layers)

# %%
vgg_16_improved = VGG_improved('VGG16',10, True)
vgg_16_improved = vgg_16_improved.to(device)
print(vgg_16_improved)
# Out:
# VGG_improved(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveMaxPool2d(output_size=(5, 5))
#   (classifier): Sequential(
#     (0): Linear(in_features=12800, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
epochs = 50
lr = 0.001

optimizer = torch.optim.SGD(vgg_16_improved.parameters(), lr=lr, momentum=0.9, weight_decay=1e-5)
loss_function = nn.CrossEntropyLoss()
#loss_function = LabelSmoothingLoss(smoothing = 0.1, reduction="mean")

vgg_improved, history_improved = model_fit(
    model = vgg_16_improved, 
    num_epochs = epochs, 
    train_loader = train_loader, 
    val_loader = val_loader,
    optimizer = optimizer,
    loss_function = loss_function,
  )
# Out:
# Train Epoch 1:
# Epoch Progress: 14% Done	Current Loss: 1.51211
# Epoch Progress: 28% Done	Current Loss: 1.41465
# Epoch Progress: 43% Done	Current Loss: 1.37934
# Epoch Progress: 57% Done	Current Loss: 1.38559
# Epoch Progress: 71% Done	Current Loss: 1.27315
# Epoch Progress: 85% Done	Current Loss: 1.55825
# Epoch Progress: 99% Done	Current Loss: 1.27044
#
# Average training loss: 0.01147, Training Accuracy: 20528/45000 (45.618%)
# Average validation loss: 0.01091, Validation Accuracy: 2523/5000 (50.460%)
#
# Epoch 1 of 50. Time taken: 97.54s
#
# Train Epoch 2:
# Epoch Progress: 14% Done	Current Loss: 1.41366
# Epoch Progress: 28% Done	Current Loss: 1.31167
# Epoch Progress: 43% Done	Current Loss: 1.36852
# Epoch Progress: 57% Done	Current Loss: 1.40233
# Epoch Progress: 71% Done	Current Loss: 1.37896
# Epoch Progress: 85% Done	Current Loss: 1.51299
# Epoch Progress: 99% Done	Current Loss: 1.22823
#
# Average training loss: 0.01057, Training Accuracy: 22720/45000 (50.489%)
# Average validation loss: 0.00990, Validation Accuracy: 2748/5000 (54.960%)
#
# Epoch 2 of 50. Time taken: 96.79s
#
# Train Epoch 3:
# Epoch Progress: 14% Done	Current Loss: 1.22340
# Epoch Progress: 28% Done	Current Loss: 1.41683
# Epoch Progress: 43% Done	Current Loss: 1.25253
# Epoch Progress: 57% Done	Current Loss: 1.35465
# Epoch Progress: 71% Done	Current Loss: 1.33886
# Epoch Progress: 85% Done	Current Loss: 1.20829
# Epoch Progress: 99% Done	Current Loss: 1.30171
#
# Average training loss: 0.00985, Training Accuracy: 24432/45000 (54.293%)
# Average validation loss: 0.00937, Validation Accuracy: 2893/5000 (57.860%)
#
# Epoch 3 of 50. Time taken: 96.75s
#
# Train Epoch 4:
# Epoch Progress: 14% Done	Current Loss: 1.36196
# Epoch Progress: 28% Done	Current Loss: 1.22945
# Epoch Progress: 43% Done	Current Loss: 0.97928
# Epoch Progress: 57% Done	Current Loss: 1.17974
# Epoch Progress: 71% Done	Current Loss: 1.29411
# Epoch Progress: 85% Done	Current Loss: 1.28825
# Epoch Progress: 99% Done	Current Loss: 1.12852
#
# Average training loss: 0.00922, Training Accuracy: 25776/45000 (57.280%)
# Average validation loss: 0.00898, Validation Accuracy: 2978/5000 (59.560%)
#
# Epoch 4 of 50. Time taken: 96.65s
#
# Train Epoch 5:
# Epoch Progress: 14% Done	Current Loss: 0.97674
# Epoch Progress: 28% Done	Current Loss: 1.01982
# Epoch Progress: 43% Done	Current Loss: 1.05330
# Epoch Progress: 57% Done	Current Loss: 1.01783
# Epoch Progress: 71% Done	Current Loss: 1.04217
# Epoch Progress: 85% Done	Current Loss: 1.08588
# Epoch Progress: 99% Done	Current Loss: 1.08985
#
# Average training loss: 0.00870, Training Accuracy: 27098/45000 (60.218%)
# Average validation loss: 0.00909, Validation Accuracy: 3024/5000 (60.480%)
#
# Epoch 5 of 50. Time taken: 96.42s
#
# Train Epoch 6:
# Epoch Progress: 14% Done	Current Loss: 1.15156
# Epoch Progress: 28% Done	Current Loss: 1.23528
# Epoch Progress: 43% Done	Current Loss: 1.04157
# Epoch Progress: 57% Done	Current Loss: 1.01830
# Epoch Progress: 71% Done	Current Loss: 0.94458
# Epoch Progress: 85% Done	Current Loss: 1.08129
# Epoch Progress: 99% Done	Current Loss: 1.05710
#
# Average training loss: 0.00823, Training Accuracy: 27991/45000 (62.202%)
# Average validation loss: 0.00816, Validation Accuracy: 3179/5000 (63.580%)
#
# Epoch 6 of 50. Time taken: 96.58s
#
# Train Epoch 7:
# Epoch Progress: 14% Done	Current Loss: 0.98715
# Epoch Progress: 28% Done	Current Loss: 0.93582
# Epoch Progress: 43% Done	Current Loss: 1.17312
# Epoch Progress: 57% Done	Current Loss: 1.01450
# Epoch Progress: 71% Done	Current Loss: 0.90262
# Epoch Progress: 85% Done	Current Loss: 0.94711
# Epoch Progress: 99% Done	Current Loss: 1.07850
#
# Average training loss: 0.00784, Training Accuracy: 28932/45000 (64.293%)
# Average validation loss: 0.00817, Validation Accuracy: 3183/5000 (63.660%)
#
# Epoch 7 of 50. Time taken: 96.35s
#
# Train Epoch 8:
# Epoch Progress: 14% Done	Current Loss: 1.13698
# Epoch Progress: 28% Done	Current Loss: 0.99113
# Epoch Progress: 43% Done	Current Loss: 0.86028
# Epoch Progress: 57% Done	Current Loss: 0.88568
# Epoch Progress: 71% Done	Current Loss: 1.04660
# Epoch Progress: 85% Done	Current Loss: 0.99480
# Epoch Progress: 99% Done	Current Loss: 0.86605
#
# Average training loss: 0.00750, Training Accuracy: 29580/45000 (65.733%)
# Average validation loss: 0.00807, Validation Accuracy: 3239/5000 (64.780%)
#
# Epoch 8 of 50. Time taken: 96.38s
#
# Train Epoch 9:
# Epoch Progress: 14% Done	Current Loss: 0.98369
# Epoch Progress: 28% Done	Current Loss: 0.88161
# Epoch Progress: 43% Done	Current Loss: 0.94775
# Epoch Progress: 57% Done	Current Loss: 1.01926
# Epoch Progress: 71% Done	Current Loss: 1.03627
# Epoch Progress: 85% Done	Current Loss: 1.14638
# Epoch Progress: 99% Done	Current Loss: 0.85989
#
# Average training loss: 0.00712, Training Accuracy: 30390/45000 (67.533%)
# Average validation loss: 0.00702, Validation Accuracy: 3452/5000 (69.040%)
#
# Epoch 9 of 50. Time taken: 96.01s
#
# Train Epoch 10:
# Epoch Progress: 14% Done	Current Loss: 0.83576
# Epoch Progress: 28% Done	Current Loss: 0.85885
# Epoch Progress: 43% Done	Current Loss: 0.81439
# Epoch Progress: 57% Done	Current Loss: 0.80323
# Epoch Progress: 71% Done	Current Loss: 0.86716
# Epoch Progress: 85% Done	Current Loss: 0.92434
# Epoch Progress: 99% Done	Current Loss: 0.76590
#
# Average training loss: 0.00677, Training Accuracy: 31150/45000 (69.222%)
# Average validation loss: 0.00720, Validation Accuracy: 3408/5000 (68.160%)
#
# Epoch 10 of 50. Time taken: 96.02s
#
# Train Epoch 11:
# Epoch Progress: 14% Done	Current Loss: 0.84557
# Epoch Progress: 28% Done	Current Loss: 0.79094
# Epoch Progress: 43% Done	Current Loss: 0.80798
# Epoch Progress: 57% Done	Current Loss: 0.90696
# Epoch Progress: 71% Done	Current Loss: 0.79202
# Epoch Progress: 85% Done	Current Loss: 0.95289
# Epoch Progress: 99% Done	Current Loss: 0.70984
#
# Average training loss: 0.00650, Training Accuracy: 31805/45000 (70.678%)
# Average validation loss: 0.00720, Validation Accuracy: 3420/5000 (68.400%)
#
# Epoch 11 of 50. Time taken: 95.93s
#
# Train Epoch 12:
# Epoch Progress: 14% Done	Current Loss: 0.80498
# Epoch Progress: 28% Done	Current Loss: 0.86783
# Epoch Progress: 43% Done	Current Loss: 0.75664
# Epoch Progress: 57% Done	Current Loss: 0.84961
# Epoch Progress: 71% Done	Current Loss: 0.79454
# Epoch Progress: 85% Done	Current Loss: 0.91276
# Epoch Progress: 99% Done	Current Loss: 0.81017
#
# Average training loss: 0.00623, Training Accuracy: 32327/45000 (71.838%)
# Average validation loss: 0.00638, Validation Accuracy: 3609/5000 (72.180%)
#
# Epoch 12 of 50. Time taken: 95.97s
#
# Train Epoch 13:
# Epoch Progress: 14% Done	Current Loss: 0.85017
# Epoch Progress: 28% Done	Current Loss: 0.64261
# Epoch Progress: 43% Done	Current Loss: 0.78740
# Epoch Progress: 57% Done	Current Loss: 0.85813
# Epoch Progress: 71% Done	Current Loss: 0.77072
# Epoch Progress: 85% Done	Current Loss: 0.81680
# Epoch Progress: 99% Done	Current Loss: 0.89286
#
# Average training loss: 0.00600, Training Accuracy: 32892/45000 (73.093%)
# Average validation loss: 0.00630, Validation Accuracy: 3604/5000 (72.080%)
#
# Epoch 13 of 50. Time taken: 95.81s
#
# Train Epoch 14:
# Epoch Progress: 14% Done	Current Loss: 0.76004
# Epoch Progress: 28% Done	Current Loss: 0.87131
# Epoch Progress: 43% Done	Current Loss: 0.82155
# Epoch Progress: 57% Done	Current Loss: 0.84956
# Epoch Progress: 71% Done	Current Loss: 0.66360
# Epoch Progress: 85% Done	Current Loss: 0.53887
# Epoch Progress: 99% Done	Current Loss: 0.70448
#
# Average training loss: 0.00582, Training Accuracy: 33353/45000 (74.118%)
# Average validation loss: 0.00654, Validation Accuracy: 3589/5000 (71.780%)
#
# Epoch 14 of 50. Time taken: 95.97s
#
# Train Epoch 15:
# Epoch Progress: 14% Done	Current Loss: 0.59662
# Epoch Progress: 28% Done	Current Loss: 0.70016
# Epoch Progress: 43% Done	Current Loss: 0.70227
# Epoch Progress: 57% Done	Current Loss: 0.75653
# Epoch Progress: 71% Done	Current Loss: 0.70465
# Epoch Progress: 85% Done	Current Loss: 0.86452
# Epoch Progress: 99% Done	Current Loss: 0.70325
#
# Average training loss: 0.00558, Training Accuracy: 33774/45000 (75.053%)
# Average validation loss: 0.00624, Validation Accuracy: 3631/5000 (72.620%)
#
# Epoch 15 of 50. Time taken: 95.88s
#
# Train Epoch 16:
# Epoch Progress: 14% Done	Current Loss: 0.53238
# Epoch Progress: 28% Done	Current Loss: 0.62428
# Epoch Progress: 43% Done	Current Loss: 0.85292
# Epoch Progress: 57% Done	Current Loss: 0.61734
# Epoch Progress: 71% Done	Current Loss: 0.58797
# Epoch Progress: 85% Done	Current Loss: 0.72350
# Epoch Progress: 99% Done	Current Loss: 0.75442
#
# Average training loss: 0.00540, Training Accuracy: 34167/45000 (75.927%)
# Average validation loss: 0.00601, Validation Accuracy: 3712/5000 (74.240%)
#
# Epoch 16 of 50. Time taken: 96.01s
#
# Train Epoch 17:
# Epoch Progress: 14% Done	Current Loss: 0.49148
# Epoch Progress: 28% Done	Current Loss: 0.78747
# Epoch Progress: 43% Done	Current Loss: 0.82218
# Epoch Progress: 57% Done	Current Loss: 0.52016
# Epoch Progress: 71% Done	Current Loss: 0.76020
# Epoch Progress: 85% Done	Current Loss: 0.66529
# Epoch Progress: 99% Done	Current Loss: 0.65689
#
# Average training loss: 0.00524, Training Accuracy: 34386/45000 (76.413%)
# Average validation loss: 0.00607, Validation Accuracy: 3685/5000 (73.700%)
#
# Epoch 17 of 50. Time taken: 96.04s
#
# Train Epoch 18:
# Epoch Progress: 14% Done	Current Loss: 0.64869
# Epoch Progress: 28% Done	Current Loss: 0.62580
# Epoch Progress: 43% Done	Current Loss: 0.64922
# Epoch Progress: 57% Done	Current Loss: 0.64461
# Epoch Progress: 71% Done	Current Loss: 0.74065
# Epoch Progress: 85% Done	Current Loss: 0.56551
# Epoch Progress: 99% Done	Current Loss: 0.56970
#
# Average training loss: 0.00502, Training Accuracy: 34935/45000 (77.633%)
# Average validation loss: 0.00608, Validation Accuracy: 3712/5000 (74.240%)
#
# Epoch 18 of 50. Time taken: 95.75s
#
# Train Epoch 19:
# Epoch Progress: 14% Done	Current Loss: 0.57797
# Epoch Progress: 28% Done	Current Loss: 0.65157
# Epoch Progress: 43% Done	Current Loss: 0.60946
# Epoch Progress: 57% Done	Current Loss: 0.75071
# Epoch Progress: 71% Done	Current Loss: 0.64029
# Epoch Progress: 85% Done	Current Loss: 0.63982
# Epoch Progress: 99% Done	Current Loss: 0.65537
#
# Average training loss: 0.00490, Training Accuracy: 35120/45000 (78.044%)
# Average validation loss: 0.00576, Validation Accuracy: 3783/5000 (75.660%)
#
# Epoch 19 of 50. Time taken: 95.81s
#
# Train Epoch 20:
# Epoch Progress: 14% Done	Current Loss: 0.72835
# Epoch Progress: 28% Done	Current Loss: 0.74650
# Epoch Progress: 43% Done	Current Loss: 0.69049
# Epoch Progress: 57% Done	Current Loss: 0.72906
# Epoch Progress: 71% Done	Current Loss: 0.57001
# Epoch Progress: 85% Done	Current Loss: 0.56491
# Epoch Progress: 99% Done	Current Loss: 0.68167
#
# Average training loss: 0.00479, Training Accuracy: 35350/45000 (78.556%)
# Average validation loss: 0.00560, Validation Accuracy: 3768/5000 (75.360%)
#
# Epoch 20 of 50. Time taken: 95.80s
#
# Train Epoch 21:
# Epoch Progress: 14% Done	Current Loss: 0.52690
# Epoch Progress: 28% Done	Current Loss: 0.62640
# Epoch Progress: 43% Done	Current Loss: 0.62203
# Epoch Progress: 57% Done	Current Loss: 0.65333
# Epoch Progress: 71% Done	Current Loss: 0.41195
# Epoch Progress: 85% Done	Current Loss: 0.73808
# Epoch Progress: 99% Done	Current Loss: 0.52476
#
# Average training loss: 0.00464, Training Accuracy: 35655/45000 (79.233%)
# Average validation loss: 0.00519, Validation Accuracy: 3854/5000 (77.080%)
#
# Epoch 21 of 50. Time taken: 95.78s
#
# Train Epoch 22:
# Epoch Progress: 14% Done	Current Loss: 0.57321
# Epoch Progress: 28% Done	Current Loss: 0.84592
# Epoch Progress: 43% Done	Current Loss: 0.51500
# Epoch Progress: 57% Done	Current Loss: 0.65869
# Epoch Progress: 71% Done	Current Loss: 0.64223
# Epoch Progress: 85% Done	Current Loss: 0.72982
# Epoch Progress: 99% Done	Current Loss: 0.60866
#
# Average training loss: 0.00451, Training Accuracy: 35824/45000 (79.609%)
# Average validation loss: 0.00555, Validation Accuracy: 3799/5000 (75.980%)
#
# Epoch 22 of 50. Time taken: 95.79s
#
# Train Epoch 23:
# Epoch Progress: 14% Done	Current Loss: 0.57190
# Epoch Progress: 28% Done	Current Loss: 0.64263
# Epoch Progress: 43% Done	Current Loss: 0.42127
# Epoch Progress: 57% Done	Current Loss: 0.49720
# Epoch Progress: 71% Done	Current Loss: 0.67981
# Epoch Progress: 85% Done	Current Loss: 0.57676
# Epoch Progress: 99% Done	Current Loss: 0.39043
#
# Average training loss: 0.00435, Training Accuracy: 36218/45000 (80.484%)
# Average validation loss: 0.00533, Validation Accuracy: 3832/5000 (76.640%)
#
# Epoch 23 of 50. Time taken: 95.61s
#
# Train Epoch 24:
# Epoch Progress: 14% Done	Current Loss: 0.53277
# Epoch Progress: 28% Done	Current Loss: 0.48729
# Epoch Progress: 43% Done	Current Loss: 0.45872
# Epoch Progress: 57% Done	Current Loss: 0.53882
# Epoch Progress: 71% Done	Current Loss: 0.57079
# Epoch Progress: 85% Done	Current Loss: 0.64739
# Epoch Progress: 99% Done	Current Loss: 0.54054
#
# Average training loss: 0.00430, Training Accuracy: 36441/45000 (80.980%)
# Average validation loss: 0.00529, Validation Accuracy: 3890/5000 (77.800%)
#
# Epoch 24 of 50. Time taken: 95.63s
#
# Train Epoch 25:
# Epoch Progress: 14% Done	Current Loss: 0.49950
# Epoch Progress: 28% Done	Current Loss: 0.52352
# Epoch Progress: 43% Done	Current Loss: 0.45899
# Epoch Progress: 57% Done	Current Loss: 0.47159
# Epoch Progress: 71% Done	Current Loss: 0.58507
# Epoch Progress: 85% Done	Current Loss: 0.63764
# Epoch Progress: 99% Done	Current Loss: 0.40746
#
# Average training loss: 0.00418, Training Accuracy: 36639/45000 (81.420%)
# Average validation loss: 0.00570, Validation Accuracy: 3747/5000 (74.940%)
#
# Epoch 25 of 50. Time taken: 95.78s
#
# Train Epoch 26:
# Epoch Progress: 14% Done	Current Loss: 0.40406
# Epoch Progress: 28% Done	Current Loss: 0.38828
# Epoch Progress: 43% Done	Current Loss: 0.48329
# Epoch Progress: 57% Done	Current Loss: 0.42353
# Epoch Progress: 71% Done	Current Loss: 0.47844
# Epoch Progress: 85% Done	Current Loss: 0.43622
# Epoch Progress: 99% Done	Current Loss: 0.70952
#
# Average training loss: 0.00403, Training Accuracy: 36925/45000 (82.056%)
# Average validation loss: 0.00547, Validation Accuracy: 3856/5000 (77.120%)
#
# Epoch 26 of 50. Time taken: 95.69s
#
# Train Epoch 27:
# Epoch Progress: 14% Done	Current Loss: 0.52201
# Epoch Progress: 28% Done	Current Loss: 0.51906
# Epoch Progress: 43% Done	Current Loss: 0.53776
# Epoch Progress: 57% Done	Current Loss: 0.51748
# Epoch Progress: 71% Done	Current Loss: 0.44928
# Epoch Progress: 85% Done	Current Loss: 0.46973
# Epoch Progress: 99% Done	Current Loss: 0.41062
#
# Average training loss: 0.00394, Training Accuracy: 37081/45000 (82.402%)
# Average validation loss: 0.00512, Validation Accuracy: 3885/5000 (77.700%)
#
# Epoch 27 of 50. Time taken: 95.80s
#
# Train Epoch 28:
# Epoch Progress: 14% Done	Current Loss: 0.39811
# Epoch Progress: 28% Done	Current Loss: 0.64563
# Epoch Progress: 43% Done	Current Loss: 0.57804
# Epoch Progress: 57% Done	Current Loss: 0.47437
# Epoch Progress: 71% Done	Current Loss: 0.62269
# Epoch Progress: 85% Done	Current Loss: 0.62037
# Epoch Progress: 99% Done	Current Loss: 0.47873
#
# Average training loss: 0.00385, Training Accuracy: 37384/45000 (83.076%)
# Average validation loss: 0.00488, Validation Accuracy: 3923/5000 (78.460%)
#
# Epoch 28 of 50. Time taken: 95.86s
#
# Train Epoch 29:
# Epoch Progress: 14% Done	Current Loss: 0.45933
# Epoch Progress: 28% Done	Current Loss: 0.41353
# Epoch Progress: 43% Done	Current Loss: 0.43531
# Epoch Progress: 57% Done	Current Loss: 0.56625
# Epoch Progress: 71% Done	Current Loss: 0.55030
# Epoch Progress: 85% Done	Current Loss: 0.41872
# Epoch Progress: 99% Done	Current Loss: 0.54967
#
# Average training loss: 0.00373, Training Accuracy: 37562/45000 (83.471%)
# Average validation loss: 0.00492, Validation Accuracy: 3966/5000 (79.320%)
#
# Epoch 29 of 50. Time taken: 95.74s
#
# Train Epoch 30:
# Epoch Progress: 14% Done	Current Loss: 0.42020
# Epoch Progress: 28% Done	Current Loss: 0.43661
# Epoch Progress: 43% Done	Current Loss: 0.55803
# Epoch Progress: 57% Done	Current Loss: 0.44086
# Epoch Progress: 71% Done	Current Loss: 0.48043
# Epoch Progress: 85% Done	Current Loss: 0.40445
# Epoch Progress: 99% Done	Current Loss: 0.49158
#
# Average training loss: 0.00365, Training Accuracy: 37668/45000 (83.707%)
# Average validation loss: 0.00489, Validation Accuracy: 3966/5000 (79.320%)
#
# Epoch 30 of 50. Time taken: 95.65s
#
# Train Epoch 31:
# Epoch Progress: 14% Done	Current Loss: 0.42766
# Epoch Progress: 28% Done	Current Loss: 0.52897
# Epoch Progress: 43% Done	Current Loss: 0.31964
# Epoch Progress: 57% Done	Current Loss: 0.50663
# Epoch Progress: 71% Done	Current Loss: 0.49184
# Epoch Progress: 85% Done	Current Loss: 0.52325
# Epoch Progress: 99% Done	Current Loss: 0.55866
#
# Average training loss: 0.00352, Training Accuracy: 37968/45000 (84.373%)
# Average validation loss: 0.00494, Validation Accuracy: 3967/5000 (79.340%)
#
# Epoch 31 of 50. Time taken: 95.65s
#
# Train Epoch 32:
# Epoch Progress: 14% Done	Current Loss: 0.39030
# Epoch Progress: 28% Done	Current Loss: 0.41556
# Epoch Progress: 43% Done	Current Loss: 0.46912
# Epoch Progress: 57% Done	Current Loss: 0.43485
# Epoch Progress: 71% Done	Current Loss: 0.45142
# Epoch Progress: 85% Done	Current Loss: 0.30499
# Epoch Progress: 99% Done	Current Loss: 0.36897
#
# Average training loss: 0.00344, Training Accuracy: 38140/45000 (84.756%)
# Average validation loss: 0.00465, Validation Accuracy: 4011/5000 (80.220%)
#
# Epoch 32 of 50. Time taken: 95.66s
#
# Train Epoch 33:
# Epoch Progress: 14% Done	Current Loss: 0.38493
# Epoch Progress: 28% Done	Current Loss: 0.37876
# Epoch Progress: 43% Done	Current Loss: 0.26712
# Epoch Progress: 57% Done	Current Loss: 0.46625
# Epoch Progress: 71% Done	Current Loss: 0.46930
# Epoch Progress: 85% Done	Current Loss: 0.33870
# Epoch Progress: 99% Done	Current Loss: 0.45091
#
# Average training loss: 0.00337, Training Accuracy: 38225/45000 (84.944%)
# Average validation loss: 0.00498, Validation Accuracy: 3930/5000 (78.600%)
#
# Epoch 33 of 50. Time taken: 95.78s
#
# Train Epoch 34:
# Epoch Progress: 14% Done	Current Loss: 0.47514
# Epoch Progress: 28% Done	Current Loss: 0.35575
# Epoch Progress: 43% Done	Current Loss: 0.63147
# Epoch Progress: 57% Done	Current Loss: 0.46089
# Epoch Progress: 71% Done	Current Loss: 0.48223
# Epoch Progress: 85% Done	Current Loss: 0.39586
# Epoch Progress: 99% Done	Current Loss: 0.47800
#
# Average training loss: 0.00327, Training Accuracy: 38453/45000 (85.451%)
# Average validation loss: 0.00496, Validation Accuracy: 3980/5000 (79.600%)
#
# Epoch 34 of 50. Time taken: 95.63s
#
# Train Epoch 35:
# Epoch Progress: 14% Done	Current Loss: 0.42421
# Epoch Progress: 28% Done	Current Loss: 0.45332
# Epoch Progress: 43% Done	Current Loss: 0.41149
# Epoch Progress: 57% Done	Current Loss: 0.35236
# Epoch Progress: 71% Done	Current Loss: 0.46309
# Epoch Progress: 85% Done	Current Loss: 0.60819
# Epoch Progress: 99% Done	Current Loss: 0.39560
#
# Average training loss: 0.00323, Training Accuracy: 38521/45000 (85.602%)
# Average validation loss: 0.00455, Validation Accuracy: 4042/5000 (80.840%)
#
# Epoch 35 of 50. Time taken: 95.63s
#
# Train Epoch 36:
# Epoch Progress: 14% Done	Current Loss: 0.39230
# Epoch Progress: 28% Done	Current Loss: 0.45453
# Epoch Progress: 43% Done	Current Loss: 0.43073
# Epoch Progress: 57% Done	Current Loss: 0.43477
# Epoch Progress: 71% Done	Current Loss: 0.35667
# Epoch Progress: 85% Done	Current Loss: 0.38278
# Epoch Progress: 99% Done	Current Loss: 0.34274
#
# Average training loss: 0.00311, Training Accuracy: 38846/45000 (86.324%)
# Average validation loss: 0.00523, Validation Accuracy: 3916/5000 (78.320%)
#
# Epoch 36 of 50. Time taken: 95.66s
#
# Train Epoch 37:
# Epoch Progress: 14% Done	Current Loss: 0.30342
# Epoch Progress: 28% Done	Current Loss: 0.43894
# Epoch Progress: 43% Done	Current Loss: 0.56128
# Epoch Progress: 57% Done	Current Loss: 0.34665
# Epoch Progress: 71% Done	Current Loss: 0.39972
# Epoch Progress: 85% Done	Current Loss: 0.41680
# Epoch Progress: 99% Done	Current Loss: 0.33482
#
# Average training loss: 0.00303, Training Accuracy: 38961/45000 (86.580%)
# Average validation loss: 0.00465, Validation Accuracy: 3996/5000 (79.920%)
#
# Epoch 37 of 50. Time taken: 95.78s
#
# Train Epoch 38:
# Epoch Progress: 14% Done	Current Loss: 0.29932
# Epoch Progress: 28% Done	Current Loss: 0.26414
# Epoch Progress: 43% Done	Current Loss: 0.25135
# Epoch Progress: 57% Done	Current Loss: 0.41776
# Epoch Progress: 71% Done	Current Loss: 0.32908
# Epoch Progress: 85% Done	Current Loss: 0.44285
# Epoch Progress: 99% Done	Current Loss: 0.47329
#
# Average training loss: 0.00297, Training Accuracy: 39075/45000 (86.833%)
# Average validation loss: 0.00481, Validation Accuracy: 3994/5000 (79.880%)
#
# Epoch 38 of 50. Time taken: 95.72s
#
# Train Epoch 39:
# Epoch Progress: 14% Done	Current Loss: 0.42161
# Epoch Progress: 28% Done	Current Loss: 0.26687
# Epoch Progress: 43% Done	Current Loss: 0.48629
# Epoch Progress: 57% Done	Current Loss: 0.26650
# Epoch Progress: 71% Done	Current Loss: 0.55873
# Epoch Progress: 85% Done	Current Loss: 0.35654
# Epoch Progress: 99% Done	Current Loss: 0.36954
#
# Average training loss: 0.00288, Training Accuracy: 39253/45000 (87.229%)
# Average validation loss: 0.00486, Validation Accuracy: 4002/5000 (80.040%)
#
# Epoch 39 of 50. Time taken: 95.60s
#
# Train Epoch 40:
# Epoch Progress: 14% Done	Current Loss: 0.41613
# Epoch Progress: 28% Done	Current Loss: 0.25816
# Epoch Progress: 43% Done	Current Loss: 0.37157
# Epoch Progress: 57% Done	Current Loss: 0.25084
# Epoch Progress: 71% Done	Current Loss: 0.46762
# Epoch Progress: 85% Done	Current Loss: 0.26971
# Epoch Progress: 99% Done	Current Loss: 0.36868
#
# Average training loss: 0.00284, Training Accuracy: 39348/45000 (87.440%)
# Average validation loss: 0.00451, Validation Accuracy: 4087/5000 (81.740%)
#
# Epoch 40 of 50. Time taken: 95.68s
#
# Train Epoch 41:
# Epoch Progress: 14% Done	Current Loss: 0.23526
# Epoch Progress: 28% Done	Current Loss: 0.40878
# Epoch Progress: 43% Done	Current Loss: 0.29299
# Epoch Progress: 57% Done	Current Loss: 0.34692
# Epoch Progress: 71% Done	Current Loss: 0.32842
# Epoch Progress: 85% Done	Current Loss: 0.28833
# Epoch Progress: 99% Done	Current Loss: 0.36042
#
# Average training loss: 0.00275, Training Accuracy: 39487/45000 (87.749%)
# Average validation loss: 0.00481, Validation Accuracy: 3990/5000 (79.800%)
#
# Epoch 41 of 50. Time taken: 95.64s
#
# Train Epoch 42:
# Epoch Progress: 14% Done	Current Loss: 0.29230
# Epoch Progress: 28% Done	Current Loss: 0.39776
# Epoch Progress: 43% Done	Current Loss: 0.36466
# Epoch Progress: 57% Done	Current Loss: 0.30317
# Epoch Progress: 71% Done	Current Loss: 0.30776
# Epoch Progress: 85% Done	Current Loss: 0.23975
# Epoch Progress: 99% Done	Current Loss: 0.38156
#
# Average training loss: 0.00272, Training Accuracy: 39566/45000 (87.924%)
# Average validation loss: 0.00451, Validation Accuracy: 4072/5000 (81.440%)
#
# Epoch 42 of 50. Time taken: 95.80s
#
# Train Epoch 43:
# Epoch Progress: 14% Done	Current Loss: 0.29431
# Epoch Progress: 28% Done	Current Loss: 0.28814
# Epoch Progress: 43% Done	Current Loss: 0.38778
# Epoch Progress: 57% Done	Current Loss: 0.43903
# Epoch Progress: 71% Done	Current Loss: 0.35168
# Epoch Progress: 85% Done	Current Loss: 0.41688
# Epoch Progress: 99% Done	Current Loss: 0.22027
#
# Average training loss: 0.00265, Training Accuracy: 39646/45000 (88.102%)
# Average validation loss: 0.00446, Validation Accuracy: 4059/5000 (81.180%)
#
# Epoch 43 of 50. Time taken: 95.85s
#
# Train Epoch 44:
# Epoch Progress: 14% Done	Current Loss: 0.25137
# Epoch Progress: 28% Done	Current Loss: 0.27947
# Epoch Progress: 43% Done	Current Loss: 0.30643
# Epoch Progress: 57% Done	Current Loss: 0.24103
# Epoch Progress: 71% Done	Current Loss: 0.35871
# Epoch Progress: 85% Done	Current Loss: 0.45140
# Epoch Progress: 99% Done	Current Loss: 0.23096
#
# Average training loss: 0.00255, Training Accuracy: 39929/45000 (88.731%)
# Average validation loss: 0.00454, Validation Accuracy: 4073/5000 (81.460%)
#
# Epoch 44 of 50. Time taken: 95.66s
#
# Train Epoch 45:
# Epoch Progress: 14% Done	Current Loss: 0.27628
# Epoch Progress: 28% Done	Current Loss: 0.20408
# Epoch Progress: 43% Done	Current Loss: 0.35426
# Epoch Progress: 57% Done	Current Loss: 0.33505
# Epoch Progress: 71% Done	Current Loss: 0.35805
# Epoch Progress: 85% Done	Current Loss: 0.32684
# Epoch Progress: 99% Done	Current Loss: 0.26459
#
# Average training loss: 0.00248, Training Accuracy: 40050/45000 (89.000%)
# Average validation loss: 0.00462, Validation Accuracy: 4066/5000 (81.320%)
#
# Epoch 45 of 50. Time taken: 95.61s
#
# Train Epoch 46:
# Epoch Progress: 14% Done	Current Loss: 0.30497
# Epoch Progress: 28% Done	Current Loss: 0.27239
# Epoch Progress: 43% Done	Current Loss: 0.31217
# Epoch Progress: 57% Done	Current Loss: 0.29934
# Epoch Progress: 71% Done	Current Loss: 0.29703
# Epoch Progress: 85% Done	Current Loss: 0.34985
# Epoch Progress: 99% Done	Current Loss: 0.39276
#
# Average training loss: 0.00241, Training Accuracy: 40167/45000 (89.260%)
# Average validation loss: 0.00463, Validation Accuracy: 4050/5000 (81.000%)
#
# Epoch 46 of 50. Time taken: 95.60s
#
# Train Epoch 47:
# Epoch Progress: 14% Done	Current Loss: 0.54309
# Epoch Progress: 28% Done	Current Loss: 0.30800
# Epoch Progress: 43% Done	Current Loss: 0.24325
# Epoch Progress: 57% Done	Current Loss: 0.30543
# Epoch Progress: 71% Done	Current Loss: 0.27311
# Epoch Progress: 85% Done	Current Loss: 0.23650
# Epoch Progress: 99% Done	Current Loss: 0.38897
#
# Average training loss: 0.00239, Training Accuracy: 40211/45000 (89.358%)
# Average validation loss: 0.00423, Validation Accuracy: 4106/5000 (82.120%)
#
# Epoch 47 of 50. Time taken: 95.64s
#
# Train Epoch 48:
# Epoch Progress: 14% Done	Current Loss: 0.30986
# Epoch Progress: 28% Done	Current Loss: 0.27913
# Epoch Progress: 43% Done	Current Loss: 0.24810
# Epoch Progress: 57% Done	Current Loss: 0.33135
# Epoch Progress: 71% Done	Current Loss: 0.35129
# Epoch Progress: 85% Done	Current Loss: 0.30150
# Epoch Progress: 99% Done	Current Loss: 0.30965
#
# Average training loss: 0.00232, Training Accuracy: 40326/45000 (89.613%)
# Average validation loss: 0.00421, Validation Accuracy: 4157/5000 (83.140%)
#
# Epoch 48 of 50. Time taken: 95.76s
#
# Train Epoch 49:
# Epoch Progress: 14% Done	Current Loss: 0.23471
# Epoch Progress: 28% Done	Current Loss: 0.15347
# Epoch Progress: 43% Done	Current Loss: 0.29939
# Epoch Progress: 57% Done	Current Loss: 0.33611
# Epoch Progress: 71% Done	Current Loss: 0.26184
# Epoch Progress: 85% Done	Current Loss: 0.34529
# Epoch Progress: 99% Done	Current Loss: 0.25379
#
# Average training loss: 0.00228, Training Accuracy: 40429/45000 (89.842%)
# Average validation loss: 0.00464, Validation Accuracy: 4037/5000 (80.740%)
#
# Epoch 49 of 50. Time taken: 95.66s
#
# Train Epoch 50:
# Epoch Progress: 14% Done	Current Loss: 0.28098
# Epoch Progress: 28% Done	Current Loss: 0.33995
# Epoch Progress: 43% Done	Current Loss: 0.31045
# Epoch Progress: 57% Done	Current Loss: 0.23750
# Epoch Progress: 71% Done	Current Loss: 0.24938
# Epoch Progress: 85% Done	Current Loss: 0.21653
# Epoch Progress: 99% Done	Current Loss: 0.35522
#
# Average training loss: 0.00226, Training Accuracy: 40565/45000 (90.144%)
# Average validation loss: 0.00481, Validation Accuracy: 4050/5000 (81.000%)
#
# Epoch 50 of 50. Time taken: 95.78s
#
# Total time taken: 4795.59s

# %%
images, labels, pred_labels = test(vgg_improved, test_loader)
# Out:
# Test set Accuracy: 8246/10000 (82.460%)

# %%
improved_model = '/content/vgg16_improved_mnist.pth'

save_model(vgg_improved, improved_model)

# %%
plot_results(epochs, history_improved, info='VGG', name='improved_VGG_16_plot')

# %%
plot_confusion_matrix(labels, pred_labels, classes)
# Out:
# array([[906,  22,  19,   2,   8,   0,   2,   9,  29,   3],
#        [  9, 976,   0,   1,   0,   0,   0,   2,   6,   6],
#        [ 48,  12, 729,  15,  55,   9,  57,  53,  15,   7],
#        [ 26,  22,  40, 583,  48,  93,  48,  84,  47,   9],
#        [ 13,   6,  22,  16, 801,  10,  33,  89,   9,   1],
#        [ 10,  11,  20,  69,  41, 715,  18,  97,   9,  10],
#        [ 10,   6,  13,  29,  15,   8, 899,  12,   7,   1],
#        [ 18,   4,   5,   5,   9,   3,   2, 944,   3,   7],
#        [ 51,  22,   1,   0,   1,   1,   3,   1, 915,   5],
#        [ 42, 149,   1,   0,   2,   2,   4,   3,  19, 778]])

# %%
plot_incorrect(images, labels, pred_labels)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
